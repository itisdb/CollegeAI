# %%
import os, sys
PWD = os.getenv('PWD')

os.chdir(PWD)
sys.path.insert(0, os.getenv('PWD'))
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "settings.local")

import django
django.setup()

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

# %%
from college.models import College

# %%
c = College.objects.first()

# %%
c
# Out:
# <College: Army Institute of Technology (AIT), Pune>

# %%
c.scraping_urls
# Out:
# ['https://www.google.com/maps/place/Army+Institute+Of+Management+And+Technology+(AIMT)/@28.4417728,77.5051757,17z/data=!4m7!3m6!1s0x390cc1b67ebfa39f:0xcfb987f8beed66d2!8m2!3d28.4417728!4d77.5073644!9m1!1b1',
#  'https://www.careers360.com/colleges/army-institute-of-technology-pune/reviews',
#  'https://www.shiksha.com/college/ait-army-institute-of-technology-dighi-hills-pune-19534/reviews',
#  'https://collegedunia.com/college/12868-army-institute-of-technology-ait-pune/reviews']

# %%
c.scraping_urls[1]
# Out:
# 'https://www.careers360.com/colleges/army-institute-of-technology-pune/reviews'

# %%
c1 = College.objects.filter(abbreviated_name__icontains='IIT')

# %%
c1
# Out:
# <QuerySet [<College: Jaypee Institute of Information Technology (JIIT ), Noida>, <College: IIT Tirupati, Tirupati>, <College: IIT Bhilai, Bhilai>, <College: IIT Palakkad, Palakkad>, <College: IIT Jammu, Jammu>, <College: IIT Goa, Goa>, <College: IIT Gandhinagar, Gandhinagar>, <College: Indian Institute of Information Technology (IIIT), Guwahati>, <College: IIIT Bangalore, Bangalore>, <College: IIT Jodhpur, Jodhpur>, <College: IIIT Hyderabad, Hyderabad>, <College: KIIT University, Bhubaneswar>, <College: IIT Mandi, Mandi>, <College: IIT Patna, Patna>, <College: IIT Ropar, Rupnagar>, <College: IIT Gandhinagar, Gandhinagar>, <College: IIT Bhubaneswar, Bhubaneswar>, <College: IIITDM Kancheepuram, Chennai>, <College: LNMIIT Jaipur, Jaipur>, <College: IIT (ISM) Dhanbad, Dhanbad>, '...(remaining elements truncated)...']>

# %%
type(c1)
# Out:
# django.db.models.query.QuerySet

# %%
len(c1)
# Out:
# 30

# %%
c.full_name
# Out:
# 'Army Institute of Technology (AIT), Pune'

# %%
print(c.abbreviated_name)
# Out:
# Army Institute of Technology (AIT)

# %%
print(c.meta_title)
print(c.meta)
# Out:
# Army Institute of Technology (AIT) - Info, Ranking, Courses, Fees, Cutoff & Placements; Placements 2021| mycollegeai
# Army Institute of Technology (AIT) - Get to know all the details about the courses offered, admission process, fee structure, ranking, student reviews, cut off, facilities, placements etc.

# %%
print(c.about_us)
print(c.meta_keywords)
print(c.established_year)
# Out:
# {'': 'The Army Institute of Management & Technology is a business school, founded  in year 1994, by the Army Welfare Education Society in Greater Noida, Uttar Pradesh. The institute is affiliated to Guru Gobind Singh Indraprastha University, Delhi.', 'Placements': 'The most crucial aspect is the placement and in this regard, AIT is one of the leading institutions. AIT students are placed with the average package of Rs.7.30 LPA in top enterprises such as  Microsoft, Amazon, ION Trading, FIGmd, Barclays and many more.', 'Fee Structure': ' AIT charges about Rs.1.8 LPA for B.E and Rs 1.21 LPA for M.E, excluding hostel & other facilities.', 'Infrastructure': 'AIT is world-class in providing its students with facilities. The infrastructure of the institute comprises boy and girl hostels, lecture centers, Wi-Fi campus, gym, cafeteria, auditorium Hospital/Medical facilities, sports complex and Library.'}
# ['Army Institute of Technology', 'ait', 'college', 'Pune', 'Maharashtra']
# 1994

# %% [markdown]
# 1. Find all IITs (You can see this query in screenshot. I need you to print name of all IITs)
# 2. Find all colleges in Delhi and print their names
# 3. Get IIT Kanpur and print all the scraping_urls.
# 4. Make a list of all scraping_urls present in all colleges. (This is special)

# %% [markdown]
# ## Find all IITs

# %%
c2 = College.objects.filter(full_name__contains='(IIT)')
c2
# Out:
# <QuerySet [<College: IIT Tirupati, Tirupati>, <College: IIT Bhilai, Bhilai>, <College: IIT Palakkad, Palakkad>, <College: IIT Jammu, Jammu>, <College: IIT Goa, Goa>, <College: IIT Gandhinagar, Gandhinagar>, <College: IIT Jodhpur, Jodhpur>, <College: IIT Patna, Patna>, <College: IIT (ISM) Dhanbad, Dhanbad>, <College: IIT Indore, Indore>, <College: IIT Hyderabad, Hyderabad>, <College: IIT Guwahati, Guwahati>, <College: IIT Roorkee, Roorkee>, <College: IIT Kharagpur, Kharagpur>, <College: IIT Kanpur, Kanpur>, <College: IIT Bombay, Mumbai>, <College: IIT Delhi, New Delhi>, <College: IIT Madras, Chennai>]>

# %%
for c in c2:
    print(c.full_name)
# Out:
# Indian Institute of Technology (IIT), Tirupati
# Indian Institute of Technology (IIT), Bhilai
# Indian Institute of Technology (IIT), Palakkad
# Indian Institute of Technology (IIT), Jammu
# Indian Institute of Technology (IIT), Goa
# Indian Institute of Technology (IIT), Gandhinagar
# Indian Institute of Technology (IIT), Jodhpur
# Indian Institute of Technology (IIT), Patna
# Indian Institute of Technology (IIT), Dhanbad
# Indian Institute of Technology (IIT), Indore
# Indian Institute of Technology (IIT), Hyderabad
# Indian Institute of Technology (IIT), Guwahati
# Indian Institute of Technology (IIT), Roorkee
# Indian Institute of Technology (IIT), Kharagpur
# Indian Institute of Technology (IIT), Kanpur
# Indian Institute of Technology (IIT), Bombay
# Indian Institute of Technology (IIT), Delhi
# Indian Institute of Technology (IIT), Madras

# %% [markdown]
# ## Find all colleges in Delhi and print their names

# %%
c3 = College.objects.filter(city__in= ["Delhi","New Delhi"])
c3
# Out:
# <QuerySet [<College: Maharaja Agrasen Institute of Technology (MAIT), Delhi>, <College: Indraprastha Institute of Technology and Managemen, Delhi>, <College: National Institute of Technology - NIT, New Delhi>, <College: Netaji Subhas University of Technology, New Delhi>, <College: Guru Gobind Singh Indraprastha University (GGSIP), New Delhi>, <College: Indira Gandhi Delhi Technical University for Women, New Delhi>, <College: Indraprastha Institute of Information Technology, New Delhi>, <College: DTU New Delhi, New Delhi>, <College: Jamia Islamia, New Delhi>, <College: IIT Delhi, New Delhi>]>

# %%
for x in c3:
    print(x.full_name)
# Out:
# MAIT Delhi - Maharaja Agrasen Institute of Technology
# Indraprastha Institute of Technology and Management (IITM Delhi), Delhi
# NIT Delhi - National Institute of Technology
# Netaji Subhas University of Technology (NSUT), New Delhi
# Guru Gobind Singh Indraprastha University (GGSIP), New Delhi
# Indira Gandhi Delhi Technical University for Women (IGDTUW), New Delhi
# Indraprastha Institute of Information Technology(IIIT), Delhi
# Delhi Technological University
# Jamia Millia Islamia
# Indian Institute of Technology (IIT), Delhi

# %% [markdown]
# ## Get IIT Kanpur and print all the scraping_urls.

# %%
c4 = College.objects.filter(full_name__contains="(IIT)").filter(city='Kanpur')
c4 = c4[0]

# %%
print(c4.scraping_urls)
# Out:
# ['https://www.shiksha.com/college/iit-kanpur-indian-institute-of-technology-25116/reviews', 'https://collegedunia.com/university/25948-indian-institute-of-technology-iit-kanpur/reviews', 'https://www.google.co.in/maps/place/Indian+Institute+of+Technology+Kanpur/@26.5097438,80.2282635,17z/data=!4m11!1m2!2m1!1siit+kanpur!3m7!1s0x399c3701c4a8be71:0x3afbe880abc38436!8m2!3d26.5123388!4d80.2329!9m1!1b1!15sCgppaXQga2FucHVyIgOIAQFaEQoDaWl0IgppaXQga2FucHVykgEKdW5pdmVyc2l0eQ?hl=en&authuser=0']

# %%
for i in c4.scraping_urls:
    print(i)
# Out:
# https://www.shiksha.com/college/iit-kanpur-indian-institute-of-technology-25116/reviews
# https://collegedunia.com/university/25948-indian-institute-of-technology-iit-kanpur/reviews
# https://www.google.co.in/maps/place/Indian+Institute+of+Technology+Kanpur/@26.5097438,80.2282635,17z/data=!4m11!1m2!2m1!1siit+kanpur!3m7!1s0x399c3701c4a8be71:0x3afbe880abc38436!8m2!3d26.5123388!4d80.2329!9m1!1b1!15sCgppaXQga2FucHVyIgOIAQFaEQoDaWl0IgppaXQga2FucHVykgEKdW5pdmVyc2l0eQ?hl=en&authuser=0

# %% [markdown]
# ## Make a list of all scraping_urls present in all colleges.

# %%
c = College.objects.all()

# %%
urls = []
for x in c:
    if x.scraping_urls is not None:
        for u in x.scraping_urls:
            urls.append(u)

# %%
len(urls)
# Out:
# 736

# %%
urls = set(urls)
len(urls)
# Out:
# 729

# %%
urls = list(urls)
len(urls)
# Out:
# 729

# %%
type(urls)
# Out:
# list

# %%
urls
# Out:
# ['https://www.shiksha.com/university/msu-the-maharaja-sayajirao-university-of-baroda-vadodara-37071/reviews',
#  'https://www.google.com/maps/place/Army+Institute+Of+Management+And+Technology+(AIMT)/@28.4417728,77.5051757,17z/data=!4m7!3m6!1s0x390cc1b67ebfa39f:0xcfb987f8beed66d2!8m2!3d28.4417728!4d77.5073644!9m1!1b1',
#  'https://www.google.com/maps/place/Chaitanya+Bharathi+Institute+of+Technology/@17.3919735,78.3172481,17z/data=!4m7!3m6!1s0x3bcb94eba8ad7c87:0xb78f51ed556f7cc5!8m2!3d17.3919735!4d78.3194368!9m1!1b1',
#  ' https://www.google.com/maps/place/Rashtrasant+Tukadoji+Maharaj+Nagpur+University/@21.1468555,79.0478733,17z/data=!4m7!3m6!1s0x3bd4c043a0dfa8c9:0x9ba851e3633b1995!8m2!3d21.1468555!4d79.050062!9m1!1b1 ',
#  'https://www.shiksha.com/college/institute-of-management-and-information-technology-biju-patnaik-university-of-technology-cuttack-37230/reviews',
#  'https://www.shiksha.com/college/nit-jalandhar-dr-b-r-ambedkar-national-institute-of-technology-24247/reviews',
# ...

# %%
y = College.objects.first()

# %%
y.full_name
# Out:
# 'Army Institute of Technology (AIT), Pune'

# %%
College.objects.get(full_name__contains="(AIT)")
# Out:
# <College: Army Institute of Technology (AIT), Pune>

# %% [markdown]
# ### Creating an object

# %%
stephens = College.objects.create(abbreviated_name="SSC")

# %%
stephens
# Out:
# <College: SSC, None>

# %%
print(stephens.full_name)
# Out:
# None

# %%
College.objects.get(abbreviated_name="SSC")
# Out:
# <College: SSC, None>

# %% [markdown]
# ## Filters

# %%
col = College.objects.filter(full_name__startswith="Indian")

# %%
for c in col:
    print(c.full_name)
# Out:
# Indian Institute of Technology (IIT), Tirupati
# Indian Institute of Technology (IIT), Bhilai
# Indian Institute of Technology (IIT), Palakkad
# Indian Institute of Technology (IIT), Jammu
# Indian Institute of Technology (IIT), Goa
# Indian Institute of Technology (IIT), Gandhinagar
# Indian Institute of Information Technology (IIIT), Guwahati
# Indian Institute of Science (IISc), Bangalore
# Indian Institute of Technology (IIT), Jodhpur
# Indian Maritime University (IMU), Kolkata
# Indian Institute of Space Science and Technology
# Indian Institute of Technology Mandi
# Indian Institute of Technology (IIT), Patna
# Indian Institute of Technology Ropar
# Indian Institute of Technology Gandhinagar
# Indian Institute of Technology Bhubaneswar
# Indian Institute of Engineering Science and Technology (IIEST), Shibpur
# Indian Institute of Information Technology, Design & Manufacturing (IIITDM), Kancheepuram
# Indian Institute of Technology (IIT), Dhanbad
# ...

# %%
col2 = College.objects.filter(full_name__startswith="Indian").exclude(full_name__icontains="(IIT")

# %%
for c in col2:
    print(c.full_name)
# Out:
# Indian Institute of Information Technology (IIIT), Guwahati
# Indian Institute of Science (IISc), Bangalore
# Indian Maritime University (IMU), Kolkata
# Indian Institute of Space Science and Technology
# Indian Institute of Technology Mandi
# Indian Institute of Technology Ropar
# Indian Institute of Technology Gandhinagar
# Indian Institute of Technology Bhubaneswar
# Indian Institute of Engineering Science and Technology (IIEST), Shibpur
# Indian Institute of Information Technology, Design & Manufacturing (IIITDM), Kancheepuram

# %%
# conatins are case sensitive and icontains gives case-insensitive results

# %% [markdown]
# ## Limiting Query Sets

# %%
y = College.objects.all()[:5]
y
# Out:
# <QuerySet [<College: SSC, None>, <College: Army Institute of Technology (AIT), Pune>, <College: The Northcap University (NCU), Gurgaon>, <College: Dhirubhai Ambani Institute of Information and Comm, Gandhinagar>, <College: Shoolini University of Biotechnology and Managemen, Solan>]>

# %%
for x in y:
    if x.full_name is not None:
        print(x.full_name[:5])
# Out:
# Army
# The N
# Dhiru
# Shool

# %% [markdown]
# ## Deleting a Record

# %%
College.objects.filter(abbreviated_name="SSC").delete()
# Out:
# (1, {'college.College': 1})

# %%
y
# Out:
# <QuerySet [<College: SSC, None>, <College: Army Institute of Technology (AIT), Pune>, <College: The Northcap University (NCU), Gurgaon>, <College: Dhirubhai Ambani Institute of Information and Comm, Gandhinagar>, <College: Shoolini University of Biotechnology and Managemen, Solan>]>

# %%
College.objects.all()[:5]
# Out:
# <QuerySet [<College: Army Institute of Technology (AIT), Pune>, <College: The Northcap University (NCU), Gurgaon>, <College: Dhirubhai Ambani Institute of Information and Comm, Gandhinagar>, <College: Shoolini University of Biotechnology and Managemen, Solan>, <College: Panjab University, Chandigarh>]>

# %%
College.objects.filter(abbreviated_name="SSC")
# Out:
# <QuerySet []>

# %%
for x in y:
    if x.full_name is not None:
        print(x.full_name)
# Out:
# Army Institute of Technology (AIT), Pune
# The Northcap University (NCU), Gurgaon
# Dhirubhai Ambani Institute of Information and Communication Technology (DAIICT), Gandhinagar
# Shoolini University of Biotechnology and Management Sciences (SUBMS), Solan

# %% [markdown]
# ## Exact Match

# %%
College.objects.get(full_name__exact="The Northcap University (NCU), Gurgaon")
# Out:
# <College: The Northcap University (NCU), Gurgaon>

# %%
# .filter() always gives a query set which we would have to loop over to derive the informtion
# .get() gives us 1 record or 1 object that we can directly use

# %%
College.objects.get(full_name__iexact="The northcap University (NCU), Gurgaon")
# Out:
# <College: The Northcap University (NCU), Gurgaon>

# %% [markdown]
# exact gives us the exact match and is case sensitive<br>
# iexact gives us the exact match and is case insensitive

# %% [markdown]
# ## Null entries

# %%
College.objects.filter(scraping_urls__isnull=True)
# Out:
# <QuerySet [<College: Elitte Institute of Engineering and Management, Kolkata>]>

# %%
a = College.objects.get(scraping_urls__isnull=True)

# %%
a.full_name
# Out:
# 'Elitte Institute of Engineering and Management (EIEM), Kolkata'

# %%
print(a.scraping_urls)
# Out:
# None

# %%
# isnull can be used to find missing data.

# %% [markdown]
# ## Multiple filters

# %%
b = College.objects.filter(full_name__icontains="(IIT", city = "Kanpur")
b
# Out:
# <QuerySet [<College: IIT Kanpur, Kanpur>]>

# %%
d = College.objects.filter(full_name__icontains="IIT",city__in = ["Kanpur","Delhi"])
d
# Out:
# <QuerySet [<College: Indraprastha Institute of Technology and Managemen, Delhi>, <College: IIT Kanpur, Kanpur>]>

# %%
for x in d:
    print(x.full_name)
# Out:
# Indraprastha Institute of Technology and Management (IITM Delhi), Delhi
# Indian Institute of Technology (IIT), Kanpur

# %% [markdown]
# ## Greater Than

# %%
e = College.objects.filter(established_year__gt=2015)

# %%
for x in e:
    print(x.established_year)
# Out:
# 2016
# 2016
# 2016
# 2016
# 2017
# 2021

# %% [markdown]
# Django provides F expressions to allow such comparisons.<br>
# Instances of F() act as a reference to a model field within a query. These references can then be used in query filters to compare the values of two different fields on the same model instance.<br><br>
#
# For example, to find a list of all blog entries that have had more comments than pingbacks, we construct an F() object to reference the pingback count, and use that F() object in the query:<br>
# > from django.db.models import F<br>
# > Entry.objects.filter(number_of_comments__gt=F('number_of_pingbacks'))

# %% [markdown]
# ## Min and Max

# %%
from django.db.models import Avg, Max, Min

# %%
a = College.objects.all()
print(a.aggregate(Min('established_year')))
# Out:
# {'established_year__min': '1847'}

# %%
print(a.aggregate(Max('established_year')))
# Out:
# {'established_year__max': '2021'}

# %% [markdown]
# ## Subqueries
# Those colleges that are IITs and have been established after 2010

# %%
from django.db.models import Subquery
s = College.objects.filter(full_name__icontains="IIT", established_year__in = Subquery(College.objects.filter(established_year__gt=2010).values('established_year')))

# %%
s
# Out:
# <QuerySet [<College: IIT Tirupati, Tirupati>, <College: IIT Bhilai, Bhilai>, <College: IIT Palakkad, Palakkad>, <College: IIT Jammu, Jammu>, <College: IIT Goa, Goa>, <College: Indian Institute of Information Technology (IIIT), Guwahati>]>

# %%
for x in s:
    print(x.full_name, x.established_year)
# Out:
# Indian Institute of Technology (IIT), Tirupati 2015
# Indian Institute of Technology (IIT), Bhilai 2016
# Indian Institute of Technology (IIT), Palakkad 2015
# Indian Institute of Technology (IIT), Jammu 2016
# Indian Institute of Technology (IIT), Goa 2016
# Indian Institute of Information Technology (IIIT), Guwahati 2013

# %% [markdown]
# ## querysets

# %%
queryset = College.objects.all()[:5]

# %%
print([e.abbreviated_name for e in queryset])
# Out:
# ['Army Institute of Technology (AIT)', 'The Northcap University (NCU)', 'Dhirubhai Ambani Institute of Information and Comm', 'Shoolini University of Biotechnology and Managemen', 'Panjab University']

# %%
from obito.controllers.data_sanitize.generic_scraper import Scraper

# %%
y = Scraper()
#y.invoke()
# Out:
# https://www.collegedekho.com/colleges/gandhi-institute-for-technology/reviews : Not a Recognized website
# https://www.collegedekho.com/colleges/gandhi-engineering-college/reviews : Not a Recognized website
# https://www.collegedekho.com/colleges/iit-bhilai/reviews : Not a Recognized website
# https://www.collegedekho.com/colleges/jain-university/reviews : Not a Recognized website
# https://www.collegedekho.com/colleges/school-for-management-studies-gnit-kolkata/reviews : Not a Recognized website
# https://www.collegedekho.com/colleges/jis-university-kolkata/reviews : Not a Recognized website
# https://www.collegedekho.com/colleges/jalpaiguri-government-engineering-college/reviews : Not a Recognized website
# https://www.collegedekho.com/colleges/asansol-engineering-college/reviews : Not a Recognized website
# https://www.collegedekho.com/colleges/kalyani-government-engineering-college/reviews : Not a Recognized website
# ...

# %%
from reviews.models import Review

# %%
r = Review.objects.all()

# %% [markdown]
# # Number of reviews scraped: 30,032

# %%
r
len(r)
# Out:
# 30032

# %%
r1 = r.first()

# %%
r1.comment
# Out:
# 'College has good lab facilities with experienced faculty with Wi-Fi facilities and lab assistance and large library. Also, facility of digital library is available where students can use the computers for research and ass...'

# %%
r1.college
# Out:
# <College: JSS Science and Technology University, Mysore>

# %%
print(r1.name)
# Out:
# None

# %%
r1.source
# Out:
# 2

# %%
r1.batch

# %%
r1.profile

# %%
r1.is_displayed
# Out:
# True

# %%
print(r1.comment)
# Out:
# College has good lab facilities with experienced faculty with Wi-Fi facilities and lab assistance and large library. Also, facility of digital library is available where students can use the computers for research and ass...

# %% [markdown]
# # Sanitization

# %%
d = r.filter(comment__icontains="don't")
for z in d:
    print(z.comment)

# %%
d = r.filter(comment__icontains="don't")
for x in d:
    x.comment = x.comment.replace("don't","do not")
    x.save()

# %%
d = r.filter(comment__icontains="Don't")
for x in d:
    x.comment = x.comment.replace("Don't","Do not")
    x.save()

# %%
e = d.filter(comment__icontains="don't")
for x in e:
    print(x.comment)

# %%
e
# Out:
# <QuerySet []>

# %%
d = r.filter(comment__icontains="hasn't")
for z in d:
    print(z.comment)
# Out:
# The college campus and the environment are good. The hostel facility provided by the college is good. The college hasn't completed the ten years so, in spite of that, the infrastructure is far better than the oth...
# Our batch hasn't seen the college actually due to Covid 19 but online classes are going well, teachers are like any other institute, some are really friendly, some are not. Admission was totally online, I have not visited my college physically till now.

# %%
d = r.filter(comment__icontains="hasn't")
for x in d:
    x.comment = x.comment.replace("hasn't","has not")
    x.save()
e = d.filter(comment__icontains="don't")
for x in e:
    print(x.comment)

# %%
e
# Out:
# <QuerySet []>

# %%
d = r.filter(comment__icontains="aren't")
for z in d:
    print(z.comment)
# Out:
# This college has good infrastructure and all necessary things. Among other new nits, this nit has a permanent campus and developing at a very faster rate. But one disadvantage is there is no single tree in whole campus. Teachers here are very kind and always ready to help. But There are few faculty who know the topic but aren't able to convey it to the students properly.And Every year there is a tech festival called gyanith in which you can show your talents. The average package of the institution ranges from 4-5 lakhs per annum.Though this is not impressive, around 85% of students gets placed which is good enough. But Do not expect like 24 lpa, they are just an rare case. Obviously if you work hard you may get even more than that.
# ...

# %%
d = r.filter(comment__icontains="aren't")
for x in d:
    x.comment = x.comment.replace("aren't","are not")
    x.save()
e = d.filter(comment__icontains="aren't")
for x in e:
    print(x.comment)

# %%
e
# Out:
# <QuerySet []>

# %%
d = r.filter(comment__icontains="didn't")
for z in d:
    print(z.comment)
# Out:
# My college has a very good reputation in all over Gujrat and its infrastructure is also on the top and also my college has very good placements so yeah there are no bad aspects of our college like I couldn't find anything still students say that attendance quota is highest compared to other colleges which I consider as pros of our college so we are prepared for the industry. Admissions were around July of 2018 and we had to first do the verification snd then we  were given admission in the college admission process was quite tedious as students from all Gujrat had come for admission but still we managed to get the admission. I choose this college over others for only one reason and that is highly paid placements which were comparable with the IITs so yeah that is one reason and other I found it's very old and reputed college of Gujrat so as I didn't get in direct my second priority was set to Nirma. Yes, there are blogs on their official site that have formally describe the fea.
# ...

# %%
d = r.filter(comment__icontains="didn't")
for x in d:
    x.comment = x.comment.replace("didn't","did not")
    x.comment = x.comment.replace("Didn't","Did not")
    x.save()
e = d.filter(comment__icontains="didn't")
for x in e:
    print(x.comment)

# %%
e
# Out:
# <QuerySet []>

# %%
d = r.filter(comment__icontains="can't")
for z in d:
    print(z.comment)
# Out:
# 1. First of all a very good package you can achieve gives so many opportunities not just ended up into job in big mnc but for start-up innovations ideas you can learn from mentors
# 2. A very wide range of choices for your career you can choose as it is a high curriculum activity active college acting public speaking theatre sports
# 3 activities for students like treasure quest during techno search music competition clubs like roobroo to show their talent dancing poetry  artistic and so much
# 4 approx every weak college organize some important events in the main hall to motivate the students
# Like meeting with ips ias of the cities founders of a great organization
# Not for just studies related, like entertainment encouragement musicians and all and so much more in coolege i can't just describe in some words.
# ...

# %%
d = r.filter(comment__icontains="can't")
for x in d:
    x.comment = x.comment.replace("can't","can not")
    x.comment = x.comment.replace("Can't","Can not")
    x.save()
e = d.filter(comment__icontains="can't")
for x in e:
    print(x.comment)

# %%
d = r.filter(comment__icontains="couldn't")
i=0
for z in d:
    i=i+1
print(i)
for x in d:
    x.comment = x.comment.replace("couldn't","could not")
    x.comment = x.comment.replace("Couldn't","Could not")
    x.save()
e = d.filter(comment__icontains="couldn't")
i=0
for z in e:
    i=i+1
print(i)
# Out:
# 4
# 0

# %%
d = r.filter(comment__icontains="hadn't")
i=0
for z in d:
    i=i+1
print("Count before sanitization : ",i)
for x in d:
    x.comment = x.comment.replace("hadn't","had not")
    x.comment = x.comment.replace("Hadn't","Had not")
    x.save()
e = d.filter(comment__icontains="hadn't")
i=0
for z in e:
    i=i+1
print("Count after sanitization : ",i)
# Out:
# Count before sanitization :  0
# Count after sanitization :  0

# %%
d = r.filter(comment__icontains="hasn't")
i=0
for z in d:
    i=i+1
print("Count before sanitization : ",i)
for x in d:
    x.comment = x.comment.replace("hasn't","has not")
    x.comment = x.comment.replace("Hasn't","Has not")
    x.save()
e = d.filter(comment__icontains="hasn't")
i=0
for z in e:
    i=i+1
print("Count after sanitization : ",i)
# Out:
# Count before sanitization :  0
# Count after sanitization :  0

# %%
d = r.filter(comment__icontains="isn't")
i=0
for z in d:
    i=i+1
print("Count before sanitization : ",i)
for x in d:
    x.comment = x.comment.replace("isn't","is not")
    x.comment = x.comment.replace("Isn't","Is not")
    x.save()
e = d.filter(comment__icontains="isn't")
i=0
for z in e:
    i=i+1
print("Count after sanitization : ",i)
# Out:
# Count before sanitization :  8
# Count after sanitization :  0

# %%
d = r.filter(comment__icontains="shouldn't")
i=0
for z in d:
    i=i+1
print("Count before sanitization : ",i)
for x in d:
    x.comment = x.comment.replace("shouldn't","should not")
    x.comment = x.comment.replace("Shouldn't","Should not")
    x.save()
e = d.filter(comment__icontains="shouldn't")
i=0
for z in e:
    i=i+1
print("Count after sanitization : ",i)
# Out:
# Count before sanitization :  15
# Count after sanitization :  0

# %%
d = r.filter(comment__icontains="wasn't")
i=0
for z in d:
    i=i+1
print("Count before sanitization : ",i)
for x in d:
    x.comment = x.comment.replace("wasn't","was not")
    x.comment = x.comment.replace("Wasn't","Was not")
    x.save()
e = d.filter(comment__icontains="wasn't")
i=0
for z in e:
    i=i+1
print("Count after sanitization : ",i)
# Out:
# Count before sanitization :  9
# Count after sanitization :  0

# %%
d = r.filter(comment__icontains="weren't")
i=0
for z in d:
    i=i+1
print("Count before sanitization : ",i)
for x in d:
    x.comment = x.comment.replace("weren't","were not")
    x.comment = x.comment.replace("Weren't","Were not")
    x.save()
e = d.filter(comment__icontains="weren't")
i=0
for z in e:
    i=i+1
print("Count after sanitization : ",i)
# Out:
# Count before sanitization :  5
# Count after sanitization :  0

# %%
d = r.filter(comment__icontains="won't")
i=0
for z in d:
    i=i+1
print("Count before sanitization : ",i)
for x in d:
    x.comment = x.comment.replace("won't","would not")
    x.comment = x.comment.replace("Won't","would not")
    x.save()
e = d.filter(comment__icontains="won't")
i=0
for z in e:
    i=i+1
print("Count after sanitization : ",i)
# Out:
# Count before sanitization :  13
# Count after sanitization :  0

# %%
d = r.filter(comment__icontains="wouldn't")
i=0
for z in d:
    i=i+1
print("Count before sanitization : ",i)
for x in d:
    x.comment = x.comment.replace("wouldn't","would not")
    x.comment = x.comment.replace("Wouldn't","Would not")
    x.save()
e = d.filter(comment__icontains="wouldn't")
i=0
for z in e:
    i=i+1
print("Count after sanitization : ",i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-59b42e3c990b> in <module>
# ----> 1 d = r.filter(comment__icontains="wouldn't")
#       2 i=0
#       3 for z in d:
#       4     i=i+1
#       5 print("Count before sanitization : ",i)
#
# NameError: name 'r' is not defined

# %%
import os, sys
PWD = os.getenv('PWD')

os.chdir(PWD)
sys.path.insert(0, os.getenv('PWD'))
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "settings.local")

import django
django.setup()

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

from reviews.models import Review
r = Review.objects.all()

# %%
from reviews.models import Review
r = Review.objects.all()

# %%
r[:50]
# Out:
# <QuerySet [<Review: For b.tech course the professors were awesome.We can interact with them and they help us a lot.
# ...

# %%
len(r)
# Out:
# 30032

# %%
r.first().comment
# Out:
# 'For b.tech course the professors were awesome.We can interact with them and they help us a lot.\r\nIn labs and practicals they help a lot to gain knowledge and clear our doubts Very good and worthy packages based on semesters All are great in their respective fields mainly physics branch'

# %% [markdown]
# 1. "the professors were awesome"
# 2. metric - academic/placement/infrastructure
# 3. weight - 0-1

# %% [markdown]
# # Inspecting reviews for HTML tags

# %% [markdown]
# ## Shiksha

# %%
rev = r.filter(source = 2)
st= []
for s in rev:
    st.append(s.comment)
st
# Out:
# ['Wi-Fi facility is available almost all the time. I never faced a problem here. Our college provides facilities like a mess, library and hostel....',
#  'Placements in our branch are pretty good when compared to other branches. The average salary package offered is 18 LPa. Almost everyone gets placed here. I heard that the condition of placements in some branches is not so good. In the electrical engineering course, apart from non-core companies, about 15-20 core companies visit our college for placements.',
#  'The classrooms, libraries and labs are well-equipped with no doubts. The lab staff and professors are very talented. The hostel is really good, with higher flexibility. There is no curfew in hostels which makes it unique from o...',
# ...

# %% [markdown]
# ## Collegedunia

# %%
rev = r.filter(source = 3)[:20]
st= []
for s in rev:
    st.append(s.comment)
st
# Out:
# ['This college is as good as it can get given the current situation. It has achieved a lot and given its annual operation cost itself is 4. 06Cr, it is understandable that the equipment present eats most of its funds.',
#  'My all india rank in JEE Exam was 1600, I wanted to pursue a unique course after my 12th standard and so opted for this course. My Grandfather insisted me to pursue this course since this was a unique opportunity to involve in the design of ships. I had the option to choose civil engineering but in INDIA only our college and IITR kharagpur had this course so I took this course. I opted IIT MADRAS through my rank and I got this college.',
#  'I am so fortunate to study in a wonderful college. Its like a dream to get a seat in my college and if I get a chance to study again I would like to thank my management at IITM.',
# ...

# %% [markdown]
# ## Collegesearch

# %%
rev = r.filter(source = 4)[:20]
st= []
for s in rev:
    st.append(s.comment)
st
# Out:
# ['For b.tech course the professors were awesome.We can interact with them and they help us a lot.\r\nIn labs and practicals they help a lot to gain knowledge and clear our doubts Very good and worthy packages based on semesters All are great in their respective fields mainly physics branch',
#  'My college has provided me a very good environment for learning. The faculty, resources, clubs and societies are the highlight of this institution. We had 450 companies visiting us this session. I got placed in Cisco based on my understanding of technical skills. The faculty has always been of immense help to us. They help proactive students gain understanding of subject knowledge. State / National Entrance Exams',
# ...

# %%
rev = r.filter(comment__icontains="\n")
len(rev)
# Out:
# 1248

# %%
rev = r.filter(comment__icontains="\r")
len(rev)
# Out:
# 1198

# %%
rev = r.filter(comment__icontains="\r\n")
len(rev)
# Out:
# 1062

# %%
rev1 = r.filter(comment__icontains="\n")
rev2 = r.filter(comment__icontains="\r")

for s in rev1:
    s.comment = s.comment.replace('\n',"")
    s.save()
    
for s in rev2:
    s.comment = s.comment.replace('\r',"")
    s.save()

# %%
r.filter(comment__icontains = "\n")
# Out:
# <QuerySet []>

# %%
rev = r.filter(source = 4)[:10]
st= []
for s in rev:
    st.append(s.comment)
st
# Out:
# ['For b.tech course the professors were awesome.We can interact with them and they help us a lot.In labs and practicals they help a lot to gain knowledge and clear our doubts Very good and worthy packages based on semesters All are great in their respective fields mainly physics branch',
#  'My college has provided me a very good environment for learning. The faculty, resources, clubs and societies are the highlight of this institution. We had 450 companies visiting us this session. I got placed in Cisco based on my understanding of technical skills. The faculty has always been of immense help to us. They help proactive students gain understanding of subject knowledge. State / National Entrance Exams',
# ...

# %%
r.filter(comment__icontains="<")
# Out:
# <QuerySet [<Review: Admission is through WBJEE rank (<3000) which happens during May-July. Since Jadavpur University is a Tier 1 college, the placements are top-notch. 85 to 90 percentage of the students are placed here in different sectors like IT & software, consulting, finance, core, R&D, the highest package being 65 LPA. Many students get internship offers and PPOs. Infrastructure is decent considering such low fees (Rs 12000 total for 4 years). Hostel and mess facilities are good too (charges are Rs 300/month approx). There is a huge Central Library, Blue Earth Workshop, OAT, free high-speed WiFi, good classroom halls and labs. Sports facilities are fascinating for every sports lover. The extremely qualified faculties are quite helpful. The campuses are beautiful, green and very well connected. Many clubs are there attracting interested students. Research culture and alumni network are great. Various scholarships are given. I preferred it for its low fees and high national and i
# ...

# %%
r.filter(comment__icontains=">")
# Out:
# <QuerySet [<Review: The students are eligible from the 7th semester (4th year) and the internships are provided from the 4th semester (2nd year) onwards. A plethora of top-tier companies like Google, Microsoft, Apple, etc visit the college and provide several good offers. The packages may go as high as 1crore and be at around 25-30 lakhs on average for top companies like Apple, Google, and Microsoft. Around 80-90% of Students secure good placements (all students who secure >7 cpi get a placement). After securing the degree I wish to work for improving our environmental quality and make it accessible for everyone to live and prosper . I want to reduce the increasing environmental pollution as well>, <Review: Lnmiit has good alumini network. Fees structure of 2016-17 is INR 146000 per semester.Scholarship criteria is cgpa >9.0, then scholarships are available.Education loan if needed from BOB, ICICI banks.>, <Review: LNMIIT placements are good compared to many private colleges in the c
# ...

# %%
rev = r.filter(comment__icontains="\t")
for s in rev:
    s.comment = s.comment.replace('\t'," ")
    s.save()
rev = r.filter(comment__icontains="\t")
len(rev)
# Out:
# 0

# %%
# generic function:

def sanitization(r):
    try: 
        rev1 = r.filter(comment__icontains="\n")
        for s in rev1:
            s.comment = s.comment.replace("\n"," ")
            s.save()

        rev2 = r.filter(comment__icontains="\r")
        for s in rev2:
            s.comment = s.comment.replace("\r"," ")
            s.save()

        rev3 = r.filter(comment__icontains="\t")
        for s in rev3:
            s.comment = s.comment.replace("\t"," ")
            s.save()
    except:
        pass

# %%
sanitization(r)

# %%
r1 = r[:5]

# %%
i = 1
for s in r1:
    print(i, ":", s.comment, "\n")
    i=i+1
# Out:
# 1 : For b.tech course the professors were awesome.We can interact with them and they help us a lot.In labs and practicals they help a lot to gain knowledge and clear our doubts Very good and worthy packages based on semesters All are great in their respective fields mainly physics branch
#
# 2 : My college has provided me a very good environment for learning. The faculty, resources, clubs and societies are the highlight of this institution. We had 450 companies visiting us this session. I got placed in Cisco based on my understanding of technical skills. The faculty has always been of immense help to us. They help proactive students gain understanding of subject knowledge. State / National Entrance Exams
#
# ...

# %%
import pandas as pd
import numpy as np
import string,re,nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from html.parser import HTMLParser
# from translate import Translator
from googletrans import Translator

# Run this only once, then comment it out
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

##################################################### MAIN FUNCTIONS #######################################################

# Apostrophe lookup
# Apostrophe constraction map
CONTRACTION_MAP = {
"ain't": "is not",
"aren't": "are not",
"can't": "cannot",
"can't've": "cannot have",
"'cause": "because",
"could've": "could have",
"couldn't": "could not",
"couldn't've": "could not have",
"didn't": "did not",
"doesn't": "does not",
"don't": "do not",
"hadn't": "had not",
"hadn't've": "had not have",
"hasn't": "has not",
"haven't": "have not",
"he'd": "he would",
"he'd've": "he would have",
"he'll": "he will",
"he'll've": "he he will have",
"he's": "he is",
"how'd": "how did",
"how'd'y": "how do you",
"how'll": "how will",
"how's": "how is",
"I'd": "I would",
"I'd've": "I would have",
"I'll": "I will",
"I'll've": "I will have",
"I'm": "I am",
"I've": "I have",
"i'd": "i would",
"i'd've": "i would have",
"i'll": "i will",
"i'll've": "i will have",
"i'm": "i am",
"i've": "i have",
"isn't": "is not",
"it'd": "it would",
"it'd've": "it would have",
"it'll": "it will",
"it'll've": "it will have",
"it's": "it is",
"let's": "let us",
"ma'am": "madam",
"mayn't": "may not",
"might've": "might have",
"mightn't": "might not",
"mightn't've": "might not have",
"must've": "must have",
"mustn't": "must not",
"mustn't've": "must not have",
"needn't": "need not",
"needn't've": "need not have",
"o'clock": "of the clock",
"oughtn't": "ought not",
"oughtn't've": "ought not have",
"shan't": "shall not",
"sha'n't": "shall not",
"shan't've": "shall not have",
"she'd": "she would",
"she'd've": "she would have",
"she'll": "she will",
"she'll've": "she will have",
"she's": "she is",
"should've": "should have",
"shouldn't": "should not",
"shouldn't've": "should not have",
"so've": "so have",
"so's": "so as",
"that'd": "that would",
"that'd've": "that would have",
"that's": "that is",
"there'd": "there would",
"there'd've": "there would have",
"there's": "there is",
"they'd": "they would",
"they'd've": "they would have",
"they'll": "they will",
"they'll've": "they will have",
"they're": "they are",
"they've": "they have",
"to've": "to have",
"wasn't": "was not",
"we'd": "we would",
"we'd've": "we would have",
"we'll": "we will",
"we'll've": "we will have",
"we're": "we are",
"we've": "we have",
"weren't": "were not",
"what'll": "what will",
"what'll've": "what will have",
"what're": "what are",
"what's": "what is",
"what've": "what have",
"when's": "when is",
"when've": "when have",
"where'd": "where did",
"where's": "where is",
"where've": "where have",
"who'll": "who will",
"who'll've": "who will have",
"who's": "who is",
"who've": "who have",
"why's": "why is",
"why've": "why have",
"will've": "will have",
"won't": "will not",
"won't've": "will not have",
"would've": "would have",
"wouldn't": "would not",
"wouldn't've": "would not have",
"y'all": "you all",
"y'all'd": "you all would",
"y'all'd've": "you all would have",
"y'all're": "you all are",
"y'all've": "you all have",
"you'd": "you would",
"you'd've": "you would have",
"you'll": "you will",
"you'll've": "you will have",
"you're": "you are",
"you've": "you have"
}
# Punctuation lookup
PUNCTUATIONS_LOOKUP = '''!()[]{};:'"\,<>./?@#$%^&*_~--'''
# Combine repetitive whitespaces to one single whitespace
COMBINE_WHITESPACE_REGEX = re.compile(r"\s+")
# Strip trailing dots
STRIP_TRAIL = re.compile(r" …")
# Translator using Google API
translator = Translator()

# Function
def clean_reviews(text,lemmatizer = WordNetLemmatizer(), contractions = CONTRACTION_MAP,punctuations = PUNCTUATIONS_LOOKUP,combine_whitespace = COMBINE_WHITESPACE_REGEX,remove_trail = STRIP_TRAIL,translate_object = translator):
    # Translate to English if not in english
    try:
        text_translated = translate_object.translate(text,dest='en')
    except:
        text_translated = text
    # Lowercase
    text_lower = text_translated.lower()
    # Resolve contractions/apostrophe lookup
    cleaned = [contractions[word] if word in contractions else word for word in text_lower.split()]
    clean_apostrophes = " ".join(cleaned)
    # Decode emojis, symbols, signs.
    apostrophe_cleaned = clean_apostrophes.encode('ascii','ignore').decode("utf8")
    # Remove newlines, tabs and extra spaces
    strip_newline_tab = apostrophe_cleaned.translate(str.maketrans('\n\t','  ',punctuations))
    strip_whitespace = combine_whitespace.sub(" ", strip_newline_tab).strip()
    # Some reviews have --> (translated by google), in them, strip it.
    pre_final_cleaned = re.compile(r"translated by google ").sub("", strip_whitespace).strip()
    # Strip trailing dots
    strip_trails = re.compile(r" …").sub("", pre_final_cleaned).strip()
    # Remove any other non-alphanumeric characters that may have been ignored
    final_cleaned = re.sub(r'\W+', ' ', strip_trails).lstrip()
    return final_cleaned

# Clean the dataset
def cleaned_feature(dataset):
    dataset['cleaned_reviews'] = dataset['Unnamed: 0'].apply(clean_reviews)
    return dataset

############################################################################################################################
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/eshitagoel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/eshitagoel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/eshitagoel/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
for s in r1:
    s.comment = clean_reviews(s.comment)
    s.save()
i = 1
for s in r1:
    print(i, ":", s.comment, "\n")
    i=i+1
# Out:
# 1 : for btech course the professors were awesomewe can interact with them and they help us a lotin labs and practicals they help a lot to gain knowledge and clear our doubts very good and worthy packages based on semesters all are great in their respective fields mainly physics branch
#
# 2 : my college has provided me a very good environment for learning the faculty resources clubs and societies are the highlight of this institution we had 450 companies visiting us this session i got placed in cisco based on my understanding of technical skills the faculty has always been of immense help to us they help proactive students gain understanding of subject knowledge state national entrance exams
#
# ...

# %%
# Looking at some reviews: 
i = 0
for s in r[:11]:
    print(i,": ",s.comment,'\n')
    i=i+1
# Out:
# 0 :  for btech course the professors were awesomewe can interact with them and they help us a lotin labs and practicals they help a lot to gain knowledge and clear our doubts very good and worthy packages based on semesters all are great in their respective fields mainly physics branch
#
# 1 :  my college has provided me a very good environment for learning the faculty resources clubs and societies are the highlight of this institution we had 450 companies visiting us this session i got placed in cisco based on my understanding of technical skills the faculty has always been of immense help to us they help proactive students gain understanding of subject knowledge state national entrance exams
#
# ...

# %%
import pandas as pd
import re
import os, sys
PWD = os.getenv('PWD')

os.chdir(PWD)
sys.path.insert(0, os.getenv('PWD'))
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "settings.local")

import django
django.setup()

os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

from reviews.models import Review
r = Review.objects.all()

# %%
'''
for s in r:
    s.comment = s.comment.lower()
    s.save()
'''
# Out:
# '\nfor s in r:\n    s.comment = s.comment.lower()\n    s.save()\n'

# %%
# Making the list of words: 

academics = ['professors','professor','library','libraries','labs','lab','curriculum', 'education', 'teachers',
             'educated','interact','teacher','practical','higher','studies','study','learn', 'subjects','society',
             'information','researchers','lecture','tutorial','doctor','project','mentors','academics','assignment',
             'assessments','course','instructor','motivate','scholars','scholarships','quizzes','discussions',          
             'practicals', 'knowledge', 'learning', 'faculty', 'societies', 'technical', 'subject', 'faculties',
            'informed', 'doctors', 'phd', 'research','laboratories','lectures','tutorials','lecturer','seminars',
            'classes','study','books','prestigious','projects','class','lecture','mentor', 'math','physics','chemistry',
            'supervision','academic','development','assessment','assignments','courses','intelligent','instructors',
            'learned','interactive','motivating','scholar','scholarship','quiz','discussion','syllabus']


placements = ['jobs',"ctc",'placement','companies','internships','google','microsoft','cisco','facebook','banks','career',
              'interviews','consulting','amazon','tcs','wipro','apple','netflix','paytm','dell','goldman','bain',
              'ey','mnc','infosys','hcl','mahindra','adobe','samsung','morgan','stanley','deutsche','bcg','twitter',
              'sony','ibm','itc','qualcomm','hsbc','tata','walmart','flipkart','intel','training','prep',
              'mckinsey','kearney','accenture','deloitte','kpmg','software','developer','package','packages',
              'salary','salries','opportunities','recruit','hire','placed','offer','international','CV','resume',
             'job','placements','company','internship','bank','careers','interview','opportunity','recruiting']


infrastructure = ['cafeteria','building','sports','hostel','wifi','internet','mess','classrooms','halls','playground',
                 'field','labs','library','canteen','cafe','shops','stores','environment','resources','facilities',
                 'campus','accommodation','room','clubs','theatre','societies','society','bedroom','bathroom',
                 'trees','green','ventilated','spacious','furniture','electricity','assembly','sanitation','equipped',
                 'auditorium','games','gym','swimming','skating','courts','tennis','basketball','cricket',
                 'volleyball','multimedia','equipment','connectivity','printer','projector','sport','classroom',
                 'connectivity','cities','city','hall','field','lab','laboritries','rooms','club','facility','game']

# %%
lst = []
for s in r[5:500]:
    regex = re.compile(r' [\w.()]{1,2}\.')
    rep = regex.sub(" ",s.comment)
    lst.extend(rep.split("."))
lst
# Out:
# ['iit madras does not need any description',
#  ' the name itself speaks for itself',
#  "  it is india's most prestigious university",
#  ' one can go and google to find out all the details about the university',
#  ' it is best in terms of education, campus life, placements and all other things',
#  ' best in the industry! the faculty is the best here having doctors, phd holders',
#  '',
#  'awesome collage which give importance to extra curriculum with studies',
#  ' collage mainly focus on research work',
#  'best environment to grasp knowledge',
#  'various functions are conducted throughout the year and student can grow in the choice of his field',
#  'proud to be an iitian almost all students are placed all teachers are perfect state / national entrance exams',
#  'the infrastructure and opportunities in iit madras is one of the best in india',
#  ' being situated in one of the metropolis of india (chennai) certainly add to its benefit',
# ...

# %%
len(lst)
# Out:
# 2786

# %%
lst.remove('')

# %%
len(lst)
# Out:
# 2785

# %%
reviews = [i for i in lst if i != '']

# %%
len(reviews)
# Out:
# 2172

# %%
reviews
# Out:
# ['iit madras does not need any description',
#  ' the name itself speaks for itself',
#  "  it is india's most prestigious university",
#  ' one can go and google to find out all the details about the university',
#  ' it is best in terms of education, campus life, placements and all other things',
#  ' best in the industry! the faculty is the best here having doctors, phd holders',
#  'awesome collage which give importance to extra curriculum with studies',
#  ' collage mainly focus on research work',
#  'best environment to grasp knowledge',
#  'various functions are conducted throughout the year and student can grow in the choice of his field',
#  'proud to be an iitian almost all students are placed all teachers are perfect state / national entrance exams',
#  'the infrastructure and opportunities in iit madras is one of the best in india',
#  ' being situated in one of the metropolis of india (chennai) certainly add to its benefit',
# ...

# %%
a = []
p = []
i = []

for l in reviews:
    for word in academics:
        if(l.find(word) != -1):
            a.append(l)
            break
            
for l in reviews:
    for word in placements:
        if(l.find(word) != -1):
            p.append(l)
            break
            
for l in reviews:
    for word in infrastructure:
        if(l.find(word) != -1):
            i.append(l)
            break
            
print(len(a),"\n",len(p),"\n",len(i))
# Out:
# 602
#  1099
#  598

# %%
a = pd.DataFrame(a)
p = pd.DataFrame(p)
i = pd.DataFrame(i)

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/eshitagoel/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
for x in [a,p,i]:
    x.rename(columns={0:'reviews'},inplace=True)

# %%
for x in [a,p,i]:
    x['scores'] = x['reviews'].apply(lambda reviews:sid.polarity_scores(reviews))

# %%
for x in [a,p,i]:
    x['compound']  = x['scores'].apply(lambda score_dict: score_dict['compound'])

# %%
a['label'] = 'academic'
p['label'] = 'placements'
i['label'] = 'infrastructure'

# %%
df = pd.concat([a,p,i])

# %%
df.describe()
# Out:
#           compound
# count  2299.000000
# mean      0.204950
# std       0.313724
# min      -0.734400
# 25%       0.000000
# 50%       0.000000
# 75%       0.440400
# max       0.964300

# %%
df.to_csv('reviews.csv')

# %%
df[df["compound"]==0].to_csv("neutral.csv")
